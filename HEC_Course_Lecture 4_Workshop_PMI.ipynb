# %%
# %pip install --upgrade --quiet google-genai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.2/732.2 kB 13.2 MB/s eta 0:00:00

# %%
# Restart kernel after installs so that your environment can access the new packages
import IPython
app = IPython.Application.instance()
app.kernel.do_shutdown(True)
# Out:
# {'status': 'ok', 'restart': True}

# %%
import sys
# Additional authentication is required for Google Colab
if "google.colab" in sys.modules:
    # Authenticate user to Google Cloud
    from google.colab import auth
    auth.authenticate_user()

# %%
import os

from google import genai

PROJECT_ID = "arboreal-cosmos-438820-p6"  # @param {type: "string", placeholder: "[your-project-id]", isTemplate: true}
if not PROJECT_ID or PROJECT_ID == "[your-project-id]":
  PROJECT_ID = str(os.environ.get("GOOGLE_CLOUD_PROJECT"))
LOCATION = os.environ.get("GOOGLE_CLOUD_REGION", "us-central1")
client = genai.Client(vertexai=True, project=PROJECT_ID, location=LOCATION)

# %%
from IPython.display import Markdown, display
from google.genai.types import GenerateContentConfig, Part

# %%
MODEL_ID = "gemini-2.0-flash-001"  # @param {type: "string"}

# %%
audio_part = Part.from_uri(
    file_uri="gs://hec_genai_course/speech.wav",
    mime_type="audio/wav",
)

# %%
prompt = "Provide a sentiment analysis of this conversation. Use speaker A, speaker B, etc to identify speakers."
response = client.models.generate_content(
    model=MODEL_ID,
    contents=[
        audio_part,
        prompt,
    ],
)
audio_analysis = response.text
display(Markdown(audio_analysis))
# Out:
# Here's a sentiment analysis of the conversation:
#
# **Overall Sentiment:** The conversation has a **guardedly optimistic** tone, mixed with **anxiety** and **concern** about the potential pitfalls of the merger. Both speakers are aware of the benefits but are also clearly conscious of the challenges ahead.
#
# *   **Speaker A (Sarah):**
#
#     *   Exhibits a **mix of excitement and apprehension.**
#     *   Proud of achieving the new ranking.
#     *   Concerned about cultural differences, potential for cutting corners, and integration of systems.
#     *   Values agility and innovation but seeks a unified standard.
# *   **Speaker B (Hans):**
#
#     *   Shows **optimism** about the potential synergies.
#     *   Aware of the risks and emphasizes the importance of harmonizing timelines.
#     *   Worried about the loss of talent and the perception of the merger as a hostile takeover.
#     *   Values compliance and discipline but also recognizes the need for efficiency.
#
# The conversation shows a sense of shared responsibility and a desire to make the merger work, but the underlying anxieties about cultural clashes, system integration, and the potential loss of talent are undeniable.

# %%
prompt = "Generate a transcript of this conversation. Use speaker A, speaker B, etc to identify speakers."

response = client.models.generate_content(
    model=MODEL_ID,
    contents=[
        audio_part,
        prompt,
    ],
)

transcript = response.text
display(Markdown(transcript))
# Out:
# Speaker A: Well, Hans, I looked at the combined head count report this morning. It's official. We're now the third largest pharma entity on the planet. It's a bit dizzying, isn't it?
# Speaker B: It is a monumental figure, Sarah. On paper, the synergies are undeniable. Your oncology pipeline and our manufacturing footprint in Europe are a perfect match. But, as we say in Frankfurt, the devil sits in the detail.
# Speaker A: You're telling me. I'm already hearing whispers from my team in Boston. They're nervous about the German way of doing things. They're used to a very lean, rapid-fire decision-making process. They're worried that our agility is going to get swallowed up by a more, let's say, structured hierarchy.
# Speaker B: By structured, I assume you mean compliant and disciplined?
# Speaker A: My concern is the inverse, to be honest. Our board is used to five-year fiscal projections with very little variance. The US growth at all costs mentality can be quite jarring to our shareholders. I am worried that the pressure for quarterly wins from the New York side will lead us to cut corners in the long-term R&D cycles we've spent decades perfecting.
# Speaker B: It's a valid point, but if we don't harmonize our clinical trial timelines, we're going to lose our edge. I've seen your legacy SOPs, they're thorough, but they're slow. If we want to beat the competition to market with the new Alzheimer's drug, we can't wait for six levels of committee approval.
# Speaker A: Efficiency is important, yes, but we are merging two very different cultures of risk. To me, the biggest threat isn't the competition, it's the integration of our reporting systems. If our ERP systems don't speak to each other by Q3, I won't be able to give the CEO a clear picture of our cash flow. That is what keeps me awake at night.
# Speaker B: For me, it's the talent. I'm worried we're going to lose our best researchers in the culture clash. People don't just work for a paycheck, they work for a vibe. If this feels like a cold, corporate takeover instead of a partnership of equals, the brains of this company will walk right out the door to a biotech startup.
# Speaker A: On that, we are in total agreement. We must ensure this feels like a new beginning, not an occupation. I am willing to trade some of my structure for some of your speed, provided we can agree on a unified transparency standard.
# Speaker B: Deal. I think we're going to be spending a lot of time on planes between New York and Frankfurt this year, Hans.
# Speaker A: Then let us hope the coffee on the company jet is better than this.
# Speaker B: To the new venture, Sarah.
# Speaker A: To the new venture. Let's go see if we can get the rest of the C-suite on the same page.

# %%
prompt = (
    """Provide a sentiment analysis of this conversation. Use speaker A, speaker B, etc to identify speakers.
Transcript:"""
    + transcript
)

response = client.models.generate_content(
    model=MODEL_ID,
    contents=prompt,
    config=GenerateContentConfig(
        response_modalities=["TEXT"],
    ),
)

text_analysis = response.text
display(Markdown(text_analysis))
# Out:
# Here's a sentiment analysis of the conversation, broken down by speaker:
#
# **Overall Sentiment:** Cautiously optimistic, with underlying anxieties about integration challenges. While the speakers acknowledge the potential benefits of the merger, they express significant concerns about cultural clashes, operational inefficiencies, and the potential loss of talent.
#
# **Speaker A (Sarah):**
#
# *   **Initial Sentiment:** Mixed. Starts with a hint of excitement ("It's a bit dizzying, isn't it?") about the company's new size, but quickly transitions to concern.
# *   **Dominant Sentiment:** Anxious and protective. She worries about the impact of the merger on her team's agility, the company's long-term R&D focus, and the integration of reporting systems.
# *   **Specific Concerns:** Losing agility due to a more structured hierarchy, pressure for short-term gains compromising long-term R&D, ERP system integration failure, and the overall cultural clash.
# *   **Tone:** Pragmatic, cautious, and concerned. She expresses a strong sense of responsibility for protecting the aspects of her company that she values.
#
# **Speaker B (Hans):**
#
# *   **Initial Sentiment:** Measured and analytical. Acknowledges the "monumental figure" and "undeniable synergies" but immediately introduces a cautionary note ("the devil sits in the detail").
# *   **Dominant Sentiment:** Pragmatic and concerned. He echoes Sarah's concerns about cultural clashes and operational inefficiencies.
# *   **Specific Concerns:** The speed of clinical trials, potential loss of talent due to culture clash, the feeling of a "cold, corporate takeover," and the need for harmonization.
# *   **Tone:** Matter-of-fact, pragmatic, and slightly more direct in his concerns. He emphasizes the need for efficiency and harmonization.
#
# **Shift in Sentiment Towards the End:**
#
# *   There is a noticeable shift towards a more positive and collaborative sentiment at the end. Both speakers acknowledge the shared concerns and express a willingness to compromise.
# *   Speaker A expresses willingness to trade structure for speed, and Speaker B agrees to a unified transparency standard, signaling a move towards a collaborative solution.
# *   The final toasts ("To the new venture") indicate a commitment to making the merger work, despite the acknowledged challenges.
#
# **In summary:**
#
# The conversation is driven by a cautious sentiment. While there is an understanding of the strategic benefits of the merger, the speakers are primarily focused on the potential pitfalls and challenges of integrating two distinct corporate cultures. The ending offers a glimmer of hope and a commitment to collaboration, but the overall sentiment remains tinged with anxiety.

# %%
prompt = (
    """Provide a short comparison of two analyses of an audio conversation.
One was made based on a text transcript of the call, and the other is based on an audio recording.
Transcript analysis:"""
    + text_analysis
    + """Audio analysis:"""
    + audio_analysis
)

response = client.models.generate_content(
    model=MODEL_ID,
    contents=prompt,
    config=GenerateContentConfig(
        response_modalities=["TEXT"],
    ),
)

comparison = response.text
display(Markdown(comparison))
# Out:
# Here's a comparison of the two analyses:
#
# **Similarities:**
#
# *   **Overall Sentiment:** Both analyses identify a "guardedly optimistic" or "cautiously optimistic" overall sentiment, heavily influenced by anxieties about the merger's challenges.  Both acknowledge the potential benefits but highlight the underlying concerns.
# *   **Key Concerns:** Both analyses correctly identify the primary anxieties: cultural clashes, system integration issues, potential loss of talent, and the impact on agility/innovation.
# *   **Speaker-Specific Sentiments:**  Both pinpoint Sarah as more directly worried about losing agility and innovation, and Hans as concerned about potential talent loss and the perception of a hostile takeover.
# *   **Acknowledgment of Positive Shift:** Both recognize a more positive and collaborative tone toward the end, signifying a commitment to making the merger work.
#
# **Differences (Advantages of Audio Analysis):**
#
# *   **Depth of Emotional Nuance:** The audio analysis, though brief in its explanation, offers a slightly richer understanding of the emotional complexity. The transcript, relying solely on word choice, can miss subtle cues conveyed through tone of voice (e.g., hesitancy, sarcasm, genuine enthusiasm).
# *  **Speaker A (Sarah)** The audio analysis highlights that Sarah is proud of achieving the new ranking of the company, which is a key detail that the text analysis has missed.
# *   **Focus:** The transcript analysis spends more time focusing on specific concerns, while the audio analysis tends to focus more on the speakers' emotions.
#
# **In summary:**
#
# The transcript-based analysis provides a solid foundation by dissecting the explicit content of the conversation and extracting key themes and concerns. However, the audio analysis adds another layer of interpretation, capturing a richer understanding of the emotional undercurrents at play.
#
# It's important to note that a more robust audio analysis would likely involve more detailed metrics like speech rate, pitch changes, pauses, and other acoustic features, providing an even deeper and more objective assessment of sentiment and emotional state. A transcript-based analysis can be very accurate but is limited by relying on what the speakers said, rather than how they said it.

# %%
prompt = (
    """Based on the transcript, provide a recommended communication to alleviaste the most negative sentiment perceived by the transcript.
Transcript analysis:"""
    + transcript

)

response = client.models.generate_content(
    model=MODEL_ID,
    contents=prompt,
    config=GenerateContentConfig(
        response_modalities=["TEXT"],
    ),
)

recommendation = response.text
display(Markdown(recommendation))
# Out:
# The most negative sentiment expressed in the transcript revolves around the fear of **culture clash and talent loss**. Both speakers identify this as a primary concern, highlighting the potential for valuable employees to leave due to a feeling of inequity, imposition, and a negative work environment.
#
# Therefore, the recommended communication should directly address these concerns and emphasize a commitment to a respectful and collaborative integration process. Here's a communication outline, targeting both employee groups in the newly merged company:
#
# **Subject: Building Our Future Together: Embracing Our Strengths at [New Company Name]**
#
# **Body:**
#
# "Dear [Company Name] Employees,
#
# As we embark on this exciting new chapter as [New Company Name], we want to address a topic that is top of mind for many: our company culture and how we will work together moving forward.
#
# We understand that any merger brings uncertainty and potential concerns about changes to established ways of working. We want to be clear: our vision for [New Company Name] is not about one culture dominating another. It's about building a new, stronger culture that leverages the best of both [Company A] and [Company B].
#
# **Specifically, we are committed to:**
#
# *   **Valuing Diverse Perspectives:** We recognize and value the unique skills, experiences, and approaches that each team brings. We will actively foster an environment where all voices are heard and respected.
# *   **Transparent Communication:** We will maintain open and honest communication channels to keep you informed about the integration process, key decisions, and opportunities for input. Regular updates, town halls, and feedback sessions will be crucial to this process.
# *   **Collaborative Decision-Making:** We will establish cross-functional teams to ensure that key decisions are made collaboratively, drawing upon the expertise and perspectives of employees from both organizations.
# *   **Investing in Training and Development:** We will provide training and development programs to help you learn about each other's processes, systems, and cultures, facilitating seamless collaboration.
# *   **Employee Recognition and Retention:** We are committed to recognizing and retaining our talented workforce. We will be actively listening to your concerns and addressing them promptly. We will establish new programs and support ongoing initiatives focused on making [New Company Name] a great place to work.
#
# **In the coming weeks and months, you will see specific initiatives rolled out to support these commitments, including:**
#
# *   **Cross-Functional Team Projects:** Opportunities to work on joint projects with colleagues from both organizations.
# *   **Cultural Awareness Workshops:** Sessions to help you understand and appreciate the differences in our work styles and approaches.
# *   **Leadership Training Programs:** Programs to equip our leaders with the skills they need to manage diverse teams effectively.
# *   **Mentorship Programs:** Opportunities to connect with colleagues from different backgrounds and share knowledge.
#
# We believe that by working together, with mutual respect and understanding, we can create a truly exceptional company that achieves its full potential. We are committed to making this a positive and rewarding experience for every employee.
#
# We encourage you to reach out to your managers, HR representatives, or any member of the leadership team with your questions and concerns. Your feedback is invaluable to us.
#
# Sincerely,
#
# [Speaker A's Name], [Speaker A's Title]
#
# [Speaker B's Name], [Speaker B's Title]"
#
# **Key elements of this communication:**
#
# *   **Directly acknowledges concerns:** It doesn't shy away from the potential for conflict.
# *   **Emphasizes a blended culture:** Highlights the goal of creating something new, not just absorbing one culture into the other.
# *   **Specific commitments:** Provides concrete examples of actions the leadership will take to address concerns.
# *   **Open invitation to feedback:** Encourages employees to voice their concerns.
# *   **Joint endorsement:** Having both leaders sign the communication reinforces the commitment to collaboration.
#
# This type of communication, followed by consistent action, will be critical in mitigating the negative sentiment and fostering a successful integration. It's important to reiterate these themes consistently throughout the integration process.
